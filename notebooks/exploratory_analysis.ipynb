# %% [markdown]
# # Exploratory analysis — political-speech-geometry
#
# Stub notebook. Phase 0 only loads the corpus inventory; later phases add embedding/geometry exploration.
#
# Kernel: `Python (speechgeo)`.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
inventory = pd.read_csv(ROOT / 'outputs' / 'tables' / 'corpus_inventory.csv')
inventory
